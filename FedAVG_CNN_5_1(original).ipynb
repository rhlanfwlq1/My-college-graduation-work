# %%
# !pip install keras-swa==0.1.5
# Out:
# Collecting keras-swa==0.1.5
#   Downloading keras-swa-0.1.5.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: keras-swa
#   Building wheel for keras-swa (setup.py) ... done
#   Created wheel for keras-swa: filename=keras_swa-0.1.5-py3-none-any.whl size=9705 sha256=4fc886c8088c832226bb43c7d5307427b86a6fa4be6014a8cd3f202e8a47626f
#   Stored in directory: /root/.cache/pip/wheels/13/35/d3/72e8eefff7c30313a87aa5d513ac40f0c288aa9835951c8b19
# Successfully built keras-swa
# Installing collected packages: keras-swa
# Successfully installed keras-swa-0.1.5

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Fri Jan 26 13:57:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from swa.tfkeras import SWA
import tensorflow.keras.backend as K

# %%
from keras.datasets import cifar10

# %%
(trainX, trainy), (testX, testy) = cifar10.load_data()
trainX = trainX/255
testX = testX/255
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 12s 0us/step

# %%
import numpy as np
import random
import cv2
import os
import matplotlib.pyplot as plt
from imutils import paths
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import Dropout
from tensorflow.keras import backend as K

# %%
lb = LabelBinarizer()                                  #Binarize labels in a one-vs-all fashion.
trainy = lb.fit_transform(trainy)                     #Fit label binarizer and transform multi-class labels to binary labels
testy = lb.fit_transform(testy)

# %%
def label_dict(img, labels):  # creating dictionary of labels
  lab_lis = {}
  for i in range(10):
    lab_lis[i] = []          #declaring key values as labels  in dictionary
  data = list(zip(img, labels))  # list of tuples of each image and label pair
  for im, lab in data:
    idx = np.argmax(lab)
    lab_lis[idx].append((im, lab))
  return lab_lis

# %%
#テストデータラベル
def label_dict_test(img, labels):
    lab_lis = {}
    for i in range(10):
        lab_lis[i] = []
    data = list(zip(img, labels))
    for im, lab in data:
        idx = np.argmax(lab)
        lab_lis[idx].append((im, lab))
    return lab_lis

# %%
# トレーニングデータ分類
t = label_dict(trainX, trainy)
# テストデータ分類
t_test = label_dict_test(testX, testy)

# %%
unlab_data = []
unlab_img_data = []
unlab_img_lab = []
for i in range(len(t)):
  unlab_data.extend(t[i][4000:]) # extracting 1000 imgaes from each class in the training set to generate the pool of so called unlabeled set
for x,y in unlab_data:
  unlab_img_data.append(x)
  unlab_img_lab.append(y)

# %%
client_names = ["client_"+str(i) for i in range(10)]
total_data_per_client = 4000  # 各クライアントあたりの最大データ数
primary_data = int((5/6) * total_data_per_client)  # クラス0.1データ比率によるデータ数
secondary_data = total_data_per_client - primary_data  # 残りのクラスに割り当てるデータ数

# クライアント データの初期化と比率に応じて再分配
client_data = {client: [] for client in client_names}
for i in range(10):
    primary_class = i % 10  # 主要クラス選択
    secondary_class = (i + 1) % 10  # 2番目の主要クラス選択

    # 主要クラスのデータ割り当て
    client_data[client_names[i]].extend(t[primary_class][:int(primary_data/2)])
    client_data[client_names[i]].extend(t[secondary_class][:int(primary_data/2)])

    # 残りのクラスデータ割り当て
    k = 0
    per_secondary_class_data = int(secondary_data / 8)  # 残りのクラスに割り当てるデータ数（クラス2~9）
    for j in range(10):
        if j != primary_class and j != secondary_class:
            client_data["client_"+str(i)].extend(t[j][per_secondary_class_data * k : per_secondary_class_data * (k+1)])  # add secondary class data
            k += 1

# クライアント別に割り当てられたトレインデータの個数出力（クラス別）
for client in client_names:
    class_count = {str(c): 0 for c in range(10)}  # クラス別データ数の初期化
    for data in client_data[client]:
        class_label = np.argmax(data[1])  # データからクラスラベルを抽出（例:one-hotエンコードされたラベル）
        class_count[str(class_label)] += 1  # 当該クラスのデータ数の増加

    # 出力
    class_count_str = ", ".join([f"class{k}: {v}個" for k, v in class_count.items()])
    print(f"{client} has {class_count_str}")
# Out:
# client_0 has class0: 1666個, class1: 1666個, class2: 83個, class3: 83個, class4: 83個, class5: 83個, class6: 83個, class7: 83個, class8: 83個, class9: 83個
# client_1 has class0: 83個, class1: 1666個, class2: 1666個, class3: 83個, class4: 83個, class5: 83個, class6: 83個, class7: 83個, class8: 83個, class9: 83個
# client_2 has class0: 83個, class1: 83個, class2: 1666個, class3: 1666個, class4: 83個, class5: 83個, class6: 83個, class7: 83個, class8: 83個, class9: 83個
# client_3 has class0: 83個, class1: 83個, class2: 83個, class3: 1666個, class4: 1666個, class5: 83個, class6: 83個, class7: 83個, class8: 83個, class9: 83個
# client_4 has class0: 83個, class1: 83個, class2: 83個, class3: 83個, class4: 1666個, class5: 1666個, class6: 83個, class7: 83個, class8: 83個, class9: 83個
# client_5 has class0: 83個, class1: 83個, class2: 83個, class3: 83個, class4: 83個, class5: 1666個, class6: 1666個, class7: 83個, class8: 83個, class9: 83個
# client_6 has class0: 83個, class1: 83個, class2: 83個, class3: 83個, class4: 83個, class5: 83個, class6: 1666個, class7: 1666個, class8: 83個, class9: 83個
# client_7 has class0: 83個, class1: 83個, class2: 83個, class3: 83個, class4: 83個, class5: 83個, class6: 83個, class7: 1666個, class8: 1666個, class9: 83個
# client_8 has class0: 83個, class1: 83個, class2: 83個, class3: 83個, class4: 83個, class5: 83個, class6: 83個, class7: 83個, class8: 1666個, class9: 1666個
# client_9 has class0: 1666個, class1: 83個, class2: 83個, class3: 83個, class4: 83個, class5: 83個, class6: 83個, class7: 83個, class8: 83個, class9: 1666個

# %%
client_test_data = {f"client_{i}": [] for i in range(10)}

for i in range(10):
    client_name = f"client_{i}"
    client_test_data[client_name] = []

    # 主要クラスデータを比率で計算して割り当て
    primary_class_1 = i % 10
    primary_class_2 = (i + 1) % 10

    # 総データ個数を1000個に設定
    total_test_data = 1000  # 各クライアントごとの総データ個数を1000個に設定
    primary_data = int(total_test_data * 5 / 6)  # 5:1の割合で主要クラスデータ
    secondary_data = total_test_data - primary_data  # 残りのデータ

    # 主要クラスのデータ割り当て
    primary_class_1_data = primary_data // 2
    primary_class_2_data = primary_data - primary_class_1_data

    # 各クラスで割り当てるデータ数が十分であることを確認し、割り当て
    client_test_data[client_name].extend(t_test[primary_class_1][:primary_class_1_data])
    client_test_data[client_name].extend(t_test[primary_class_2][:primary_class_2_data])

    # 残りのクラスデータ割り当て
    k = 0
    per_secondary_class_data = secondary_data // 8  # 残りのクラスに割り当てるデータ数（クラス2~9）
    for j in range(10):
        if j != primary_class_1 and j != primary_class_2:
            allocation = per_secondary_class_data if k < 7 else secondary_data - per_secondary_class_data * 7
            client_test_data[client_name].extend(t_test[j][:allocation])
            k += 1

for client in client_names:
    total_test_data_count = len(client_test_data[client])
    class_count = {str(c): 0 for c in range(10)}  # クラス別データ数の初期化

    for data in client_test_data[client]:
        class_label = np.argmax(data[1])  # データからクラスラベルを抽出
        class_count[str(class_label)] += 1  # 当該クラスのデータ数の増加

    print(f"Client {client} has a total of {total_test_data_count} test data.")
    class_count_str = ", ".join([f"class{k}: {v}個" for k, v in class_count.items()])
    print(f"Class distribution: {class_count_str}")
# Out:
# Client client_0 has a total of 1000 test data.
# Class distribution: class0: 416個, class1: 417個, class2: 20個, class3: 20個, class4: 20個, class5: 20個, class6: 20個, class7: 20個, class8: 20個, class9: 27個
# Client client_1 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 416個, class2: 417個, class3: 20個, class4: 20個, class5: 20個, class6: 20個, class7: 20個, class8: 20個, class9: 27個
# Client client_2 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 416個, class3: 417個, class4: 20個, class5: 20個, class6: 20個, class7: 20個, class8: 20個, class9: 27個
# Client client_3 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 20個, class3: 416個, class4: 417個, class5: 20個, class6: 20個, class7: 20個, class8: 20個, class9: 27個
# Client client_4 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 20個, class3: 20個, class4: 416個, class5: 417個, class6: 20個, class7: 20個, class8: 20個, class9: 27個
# Client client_5 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 20個, class3: 20個, class4: 20個, class5: 416個, class6: 417個, class7: 20個, class8: 20個, class9: 27個
# Client client_6 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 20個, class3: 20個, class4: 20個, class5: 20個, class6: 416個, class7: 417個, class8: 20個, class9: 27個
# Client client_7 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 20個, class3: 20個, class4: 20個, class5: 20個, class6: 20個, class7: 416個, class8: 417個, class9: 27個
# Client client_8 has a total of 1000 test data.
# Class distribution: class0: 20個, class1: 20個, class2: 20個, class3: 20個, class4: 20個, class5: 20個, class6: 20個, class7: 27個, class8: 416個, class9: 417個
# Client client_9 has a total of 1000 test data.
# Class distribution: class0: 417個, class1: 20個, class2: 20個, class3: 20個, class4: 20個, class5: 20個, class6: 20個, class7: 20個, class8: 27個, class9: 416個

# %%
def batch(zip_data, batch_size = 40):
  data, label = zip(*zip_data)  # Unzipping the img and label pair
  dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label))) # create a dataset object to make use of other transformation attributes
  return dataset.shuffle(len(label)).batch(batch_size)# shuffles data and creates batches of size 40

# %%
client_batched = {}
for (client_name, data) in client_data.items():
  client_batched[client_name] = batch(data)

test_batched = tf.data.Dataset.from_tensor_slices((testX, testy)).batch(len(testy))
unlab_dataset = tf.data.Dataset.from_tensor_slices((unlab_img_data)).batch(len(unlab_img_data))

# %%
class MLP:
    @staticmethod
    def build():
        model = Sequential()
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3))) # 32 filters of size 3*3
        model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(AveragePooling2D((2, 2))) # aveeraging the cell cvales for size of 2*2, witha stride of 2
        model.add(Dropout(0.2))  # randomly assign the value o to nodes, with probability of 0.2
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(AveragePooling2D((2, 2)))
        model.add(Dropout(0.2))
        model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
        model.add(AveragePooling2D((2, 2)))
        model.add(Dropout(0.2))
        model.add(Flatten())
        model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
        model.add(Dropout(0.2))
        model.add(Dense(10, activation='softmax'))
        return model

# %%
model = MLP()
model = model.build()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  average_pooling2d (Average  (None, 16, 16, 32)        0
#  Pooling2D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  average_pooling2d_1 (Avera  (None, 8, 8, 64)          0
#  gePooling2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  average_pooling2d_2 (Avera  (None, 4, 4, 128)         0
#  gePooling2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550570 (2.10 MB)
# Trainable params: 550570 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
t = model.get_weights()
for v in t:
  print(np.shape(v))
# Out:
# (3, 3, 3, 32)
# (32,)
# (3, 3, 32, 32)
# (32,)
# (3, 3, 32, 64)
# (64,)
# (3, 3, 64, 64)
# (64,)
# (3, 3, 64, 128)
# (128,)
# (3, 3, 128, 128)
# (128,)
# (2048, 128)
# (128,)
# (128, 10)
# (10,)

# %%
comms_round = 40
loss='categorical_crossentropy'
metrics = ['accuracy']
optimizer = SGD(learning_rate=0.01,
                momentum=0.9
               )
optimizer2 = SGD(learning_rate=0.001,
                 momentum=0.9
               )

# %%
weight_scale = []
for (name, data) in client_data.items():
  weight_scale.append(len(data)/40000)
weight_scale = np.array(weight_scale).reshape((len(weight_scale),1))

# %%
def sum_scaled_weights(scaled_weight_list, M, unlab_data):
    avg_grad_mean = list()
    avg_grad_var = list()
    for grad_list_tuple in zip(*scaled_weight_list):
        #print(np.shape(grad_list_tuple))
        if len(np.shape(grad_list_tuple)) == 5:
          w = weight_scale.reshape((len(weight_scale), 1, 1, 1, 1))
        elif len(np.shape(grad_list_tuple)) == 4:
          w = weight_scale.reshape((len(weight_scale), 1, 1, 1))
        elif len(np.shape(grad_list_tuple)) == 3:
          w = weight_scale.reshape((len(weight_scale), 1, 1))
        else:
          w = weight_scale
        layer_mean = np.sum(grad_list_tuple*w, axis=0)
        #print(np.shape(layer_mean))
        layer_variance = np.sum(np.power(grad_list_tuple - layer_mean, 2)*w, axis = 0)
        avg_grad_mean.append(layer_mean)
        avg_grad_var.append(layer_variance)
    return avg_grad_mean


def test_model(X_test, Y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    logits = model.predict(X_test)
    loss = cce(Y_test, logits)
    acc = accuracy_score(tf.argmax(logits, axis=1), tf.argmax(Y_test, axis=1))
    print('comm_round: {} | global_acc: {:.3%} | global_loss: {}'.format(comm_round, acc, loss))
    return acc, loss

# %%
def evaluate_model_on_clients(model, client_test_data, client_names):
    results = {}
    for client_name in client_names:
        test_data, test_labels = zip(*client_test_data[client_name])
        test_data = np.array(test_data)
        test_labels = np.array(test_labels)

        test_loss, test_acc = model.evaluate(test_data, test_labels, verbose=0)

        # 結果をディクショナリーに保存
        results[client_name] = {'accuracy': test_acc, 'loss': test_loss}
    return results

# %%
all_clients_results = {}

for train_client in client_names:
    # モデルの初期化とコンパイル
    mlp_local = MLP()
    local_model = mlp_local.build()

    new_optimizer = tf.keras.optimizers.legacy.SGD(learning_rate=0.01, momentum=0.9)
    local_model.compile(loss=loss, optimizer=new_optimizer, metrics=metrics)

    # クライアントデータでモデルトレーニング
    train_data, train_labels = zip(*client_data[train_client])
    train_data = np.array(train_data)
    train_labels = np.array(train_labels)
    local_model.fit(train_data, train_labels, epochs=20, verbose=0)

    # 他のクライアントのテストデータのモデル評価
    test_results = evaluate_model_on_clients(local_model, client_test_data, client_names)
    all_clients_results[train_client] = test_results

    # 訓練されたクライアントモデルの評価結果出力
    print(f"Results for model trained on {train_client}:")
    for client, results in test_results.items():
        print(f"  Test on {client} - Accuracy: {results['accuracy']:.4f}, Loss: {results['loss']:.4f}")

    K.clear_session()
# Out:
# Results for model trained on client_0:
#   Test on client_0 - Accuracy: 0.8240, Loss: 0.6074
#   Test on client_1 - Accuracy: 0.4540, Loss: 2.0414
#   Test on client_2 - Accuracy: 0.1150, Loss: 3.2576
#   Test on client_3 - Accuracy: 0.2310, Loss: 2.6662
#   Test on client_4 - Accuracy: 0.2670, Loss: 2.5167
#   Test on client_5 - Accuracy: 0.3230, Loss: 2.3801
#   Test on client_6 - Accuracy: 0.3660, Loss: 2.3086
#   Test on client_7 - Accuracy: 0.2090, Loss: 2.8743
#   Test on client_8 - Accuracy: 0.1020, Loss: 3.6214
#   Test on client_9 - Accuracy: 0.4550, Loss: 2.3574
# Results for model trained on client_1:
#   Test on client_0 - Accuracy: 0.5110, Loss: 1.5563
#   Test on client_1 - Accuracy: 0.7810, Loss: 0.7388
#   Test on client_2 - Accuracy: 0.4030, Loss: 2.1182
#   Test on client_3 - Accuracy: 0.0560, Loss: 3.2823
#   Test on client_4 - Accuracy: 0.0550, Loss: 3.2204
#   Test on client_5 - Accuracy: 0.1030, Loss: 2.8802
#   Test on client_6 - Accuracy: 0.1370, Loss: 2.8032
#   Test on client_7 - Accuracy: 0.1550, Loss: 2.7933
#   Test on client_8 - Accuracy: 0.1620, Loss: 2.7159
#   Test on client_9 - Accuracy: 0.1740, Loss: 2.7169
# Results for model trained on client_2:
#   Test on client_0 - Accuracy: 0.4010, Loss: 1.8072
#   Test on client_1 - Accuracy: 0.5970, Loss: 1.2822
#   Test on client_2 - Accuracy: 0.7060, Loss: 0.9402
#   Test on client_3 - Accuracy: 0.3710, Loss: 2.2421
#   Test on client_4 - Accuracy: 0.0750, Loss: 3.3499
#   Test on client_5 - Accuracy: 0.0930, Loss: 3.2167
#   Test on client_6 - Accuracy: 0.1730, Loss: 2.9236
#   Test on client_7 - Accuracy: 0.2810, Loss: 2.2941
#   Test on client_8 - Accuracy: 0.2960, Loss: 2.1195
#   Test on client_9 - Accuracy: 0.3090, Loss: 2.0976
# Results for model trained on client_3:
#   Test on client_0 - Accuracy: 0.4450, Loss: 1.7429
#   Test on client_1 - Accuracy: 0.3490, Loss: 2.3271
#   Test on client_2 - Accuracy: 0.3850, Loss: 2.1861
#   Test on client_3 - Accuracy: 0.7000, Loss: 0.9392
#   Test on client_4 - Accuracy: 0.3840, Loss: 2.1969
#   Test on client_5 - Accuracy: 0.1030, Loss: 3.3005
#   Test on client_6 - Accuracy: 0.1400, Loss: 2.9768
#   Test on client_7 - Accuracy: 0.2660, Loss: 2.3799
#   Test on client_8 - Accuracy: 0.3140, Loss: 2.2540
#   Test on client_9 - Accuracy: 0.2500, Loss: 2.3950
# Results for model trained on client_4:
#   Test on client_0 - Accuracy: 0.3790, Loss: 2.0540
#   Test on client_1 - Accuracy: 0.2550, Loss: 2.5394
#   Test on client_2 - Accuracy: 0.0890, Loss: 3.3129
#   Test on client_3 - Accuracy: 0.4070, Loss: 2.1783
#   Test on client_4 - Accuracy: 0.7060, Loss: 0.9300
#   Test on client_5 - Accuracy: 0.4100, Loss: 2.0386
#   Test on client_6 - Accuracy: 0.1280, Loss: 3.4885
#   Test on client_7 - Accuracy: 0.2700, Loss: 2.9019
#   Test on client_8 - Accuracy: 0.4310, Loss: 2.0600
#   Test on client_9 - Accuracy: 0.3920, Loss: 2.1749
# Results for model trained on client_5:
#   Test on client_0 - Accuracy: 0.3650, Loss: 2.2681
#   Test on client_1 - Accuracy: 0.2380, Loss: 2.8922
#   Test on client_2 - Accuracy: 0.0960, Loss: 3.6033
#   Test on client_3 - Accuracy: 0.0830, Loss: 3.4179
#   Test on client_4 - Accuracy: 0.4120, Loss: 2.0616
#   Test on client_5 - Accuracy: 0.7740, Loss: 0.8041
#   Test on client_6 - Accuracy: 0.5500, Loss: 1.6616
#   Test on client_7 - Accuracy: 0.4090, Loss: 2.2111
#   Test on client_8 - Accuracy: 0.4400, Loss: 2.2160
#   Test on client_9 - Accuracy: 0.3600, Loss: 2.4737
# Results for model trained on client_6:
#   Test on client_0 - Accuracy: 0.3850, Loss: 2.2059
#   Test on client_1 - Accuracy: 0.2300, Loss: 2.9883
#   Test on client_2 - Accuracy: 0.0870, Loss: 3.7687
#   Test on client_3 - Accuracy: 0.0850, Loss: 3.5699
#   Test on client_4 - Accuracy: 0.0900, Loss: 3.5713
#   Test on client_5 - Accuracy: 0.4460, Loss: 2.2443
#   Test on client_6 - Accuracy: 0.8080, Loss: 0.7059
#   Test on client_7 - Accuracy: 0.6500, Loss: 1.1683
#   Test on client_8 - Accuracy: 0.3600, Loss: 2.1751
#   Test on client_9 - Accuracy: 0.3190, Loss: 2.4509
# Results for model trained on client_7:
#   Test on client_0 - Accuracy: 0.2050, Loss: 3.1317
#   Test on client_1 - Accuracy: 0.2240, Loss: 2.8903
#   Test on client_2 - Accuracy: 0.1750, Loss: 2.7806
#   Test on client_3 - Accuracy: 0.1170, Loss: 2.8802
#   Test on client_4 - Accuracy: 0.1460, Loss: 2.5793
#   Test on client_5 - Accuracy: 0.2630, Loss: 2.2219
#   Test on client_6 - Accuracy: 0.5780, Loss: 1.4581
#   Test on client_7 - Accuracy: 0.8160, Loss: 0.6875
#   Test on client_8 - Accuracy: 0.5360, Loss: 1.6890
#   Test on client_9 - Accuracy: 0.2210, Loss: 2.9632
# Results for model trained on client_8:
#   Test on client_0 - Accuracy: 0.2100, Loss: 2.4642
#   Test on client_1 - Accuracy: 0.2130, Loss: 2.4705
#   Test on client_2 - Accuracy: 0.1770, Loss: 2.6571
#   Test on client_3 - Accuracy: 0.2550, Loss: 2.3883
#   Test on client_4 - Accuracy: 0.3300, Loss: 2.2312
#   Test on client_5 - Accuracy: 0.3530, Loss: 2.1857
#   Test on client_6 - Accuracy: 0.4680, Loss: 1.7994
#   Test on client_7 - Accuracy: 0.6670, Loss: 1.1843
#   Test on client_8 - Accuracy: 0.8090, Loss: 0.6627
#   Test on client_9 - Accuracy: 0.5080, Loss: 1.5804
# Results for model trained on client_9:
#   Test on client_0 - Accuracy: 0.4480, Loss: 1.9170
#   Test on client_1 - Accuracy: 0.1630, Loss: 2.8872
#   Test on client_2 - Accuracy: 0.1890, Loss: 2.7596
#   Test on client_3 - Accuracy: 0.2360, Loss: 2.4808
#   Test on client_4 - Accuracy: 0.2560, Loss: 2.3815
#   Test on client_5 - Accuracy: 0.3060, Loss: 2.3415
#   Test on client_6 - Accuracy: 0.3070, Loss: 2.3630
#   Test on client_7 - Accuracy: 0.1550, Loss: 2.8988
#   Test on client_8 - Accuracy: 0.4180, Loss: 1.9558
#   Test on client_9 - Accuracy: 0.7580, Loss: 0.7689

# %%
# モデル平均出してM_10という新しいモデル

client_models = {}
for client in client_names:
    print(f"Training model for {client}...")
    model = MLP.build()
    model.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=0.01, momentum=0.9), metrics=['accuracy'])
    train_data, train_labels = zip(*client_data[client])

    # モデル学習とヒストリー保存
    history = model.fit(np.array(train_data), np.array(train_labels), epochs=20, verbose=0)

    # 最後のエポックの精度と損失抽出
    final_epoch_accuracy = history.history['accuracy'][-1]
    final_epoch_loss = history.history['loss'][-1]

    print(f"Train on {client} - Accuracy: {final_epoch_accuracy:.4f}, Loss: {final_epoch_loss:.4f}")

    client_models[client] = model.get_weights()


avg_weights = []
for layer in zip(*[client_models[client] for client in client_names]):
    layer_mean = np.mean(np.array([np.array(w) for w in layer]), axis=0)
    avg_weights.append(layer_mean)

model_M_10 = MLP.build()
model_M_10.set_weights(avg_weights)

# モデルM_10をコンパイル
model_M_10.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=0.01, momentum=0.9), metrics=['accuracy'])

# 各クライアントのテストデータからモデルM_10を追加学習
for client in client_names:
    print(f"Further training model M_10 with test data of {client}...")
    test_data, test_labels = zip(*client_test_data[client])

    history = model_M_10.fit(np.array(test_data), np.array(test_labels), epochs=20, verbose=0)

    final_epoch_accuracy = history.history['accuracy'][-1]
    final_epoch_loss = history.history['loss'][-1]

    print(f"Test on {client} - Accuracy: {final_epoch_accuracy:.4f}, Loss: {final_epoch_loss:.4f}")
# Out:
# Training model for client_0...
# Train on client_0 - Accuracy: 0.8551, Loss: 0.4250
# Training model for client_1...
# Train on client_1 - Accuracy: 0.8226, Loss: 0.5566
# Training model for client_2...
# Train on client_2 - Accuracy: 0.7215, Loss: 0.7733
# Training model for client_3...
# Train on client_3 - Accuracy: 0.7835, Loss: 0.6248
# Training model for client_4...
# Train on client_4 - Accuracy: 0.7595, Loss: 0.6918
# Training model for client_5...
# Train on client_5 - Accuracy: 0.8153, Loss: 0.5523
# Training model for client_6...
# Train on client_6 - Accuracy: 0.8596, Loss: 0.4357
# Training model for client_7...
# Train on client_7 - Accuracy: 0.8604, Loss: 0.4357
# Training model for client_8...
# Train on client_8 - Accuracy: 0.8651, Loss: 0.4043
# Training model for client_9...
# Train on client_9 - Accuracy: 0.8341, Loss: 0.4956
# Further training model M_10 with test data of client_0...
# Test on client_0 - Accuracy: 0.4110, Loss: 1.3843
# Further training model M_10 with test data of client_1...
# Test on client_1 - Accuracy: 0.3970, Loss: 1.3827
# Further training model M_10 with test data of client_2...
# Test on client_2 - Accuracy: 0.4140, Loss: 1.3808
# Further training model M_10 with test data of client_3...
# Test on client_3 - Accuracy: 0.3890, Loss: 1.3797
# Further training model M_10 with test data of client_4...
# Test on client_4 - Accuracy: 0.4040, Loss: 1.3852
# Further training model M_10 with test data of client_5...
# Test on client_5 - Accuracy: 0.3960, Loss: 1.3847
# Further training model M_10 with test data of client_6...
# Test on client_6 - Accuracy: 0.4090, Loss: 1.3796
# Further training model M_10 with test data of client_7...
# Test on client_7 - Accuracy: 0.4110, Loss: 1.3795
# Further training model M_10 with test data of client_8...
# Test on client_8 - Accuracy: 0.4090, Loss: 1.3805
# Further training model M_10 with test data of client_9...
# Test on client_9 - Accuracy: 0.4210, Loss: 1.3811

# %%
client_names = [f"client_{i}" for i in range(10)]
test_accuracies = [
    0.4120, 0.3930, 0.4050, 0.4270, 0.4150, 0.3970, 0.4250, 0.3940, 0.4090, 0.4210
]
test_losses = [
    1.3807, 1.3841, 1.3803, 1.3764, 1.3848, 1.3822, 1.3800, 1.3835, 1.3805, 1.3811
]

x = np.arange(len(client_names))

width = 0.35

fig, ax1 = plt.subplots(figsize=(8, 6))

rects1 = ax1.bar(x - width/2, test_accuracies, width, label='Accuracy', color='tab:blue')
ax1.set_xlabel('Client')
ax1.set_ylabel('Accuracy', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_xticks(x)
ax1.set_xticklabels(client_names)

ax2 = ax1.twinx()
rects2 = ax2.bar(x + width/2, test_losses, width, label='Loss', color='tab:red')
ax2.set_ylabel('Loss', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('Performance of Model M_10 on Test Data(5:1)')

fig.tight_layout()
plt.show()

# %%
# M_10モデル初期化
model_M_10 = MLP.build()
model_M_10.set_weights(avg_weights)

# 各通信ラウンド実行
for comm_round in range(comms_round):
    print(f"---- Round {comm_round} ----")
    # ローカルモデル重み付けリストの初期化
    scaled_local_weight_list = list()

    # クライアント名を並べ替える
    sorted_client_names = sorted(client_names)

    # 各クライアントのトレーニングデータセットでグローバルモデル学習
    for client in sorted_client_names:
        train_data, train_labels = zip(*client_data[client])
        train_data = np.array(train_data)
        train_labels = np.array(train_labels)

        # M_10モデルで訓練データ学習
        model_M_10.compile(loss=loss,
                           optimizer=SGD(learning_rate=0.01, momentum=0.9),
                           metrics=metrics)
        model_M_10.fit(train_data, train_labels, epochs=20, verbose=0)
        scaled_local_weight_list.append(model_M_10.get_weights())

    # ローカルモデルの重み付けを平均化してグローバルモデルを更新
    new_global_weights = sum_scaled_weights(scaled_local_weight_list, 10, unlab_dataset)
    model_M_10.set_weights(new_global_weights)

    # 各クライアントのテストデータセットでグローバルモデル評価
    for client in sorted_client_names:
        test_data, test_labels = zip(*client_test_data[client])
        test_data = np.array(test_data)
        test_labels = np.array(test_labels)

        # M_10 モデルでテストデータ評価
        test_loss, test_acc = model_M_10.evaluate(test_data, test_labels, verbose=0)
        print(f"Client {client} - Accuracy: {test_acc:.4f}, Loss: {test_loss:.4f}")
    print("---- End of Round ----\n")
# Out:
# ---- Round 0 ----
# Client client_0 - Accuracy: 0.5670, Loss: 1.3087
# Client client_1 - Accuracy: 0.4530, Loss: 1.5059
# Client client_2 - Accuracy: 0.2260, Loss: 1.9907
# Client client_3 - Accuracy: 0.3690, Loss: 1.6535
# Client client_4 - Accuracy: 0.4630, Loss: 1.5035
# Client client_5 - Accuracy: 0.5740, Loss: 1.2492
# Client client_6 - Accuracy: 0.6220, Loss: 1.1786
# Client client_7 - Accuracy: 0.5300, Loss: 1.3522
# Client client_8 - Accuracy: 0.5120, Loss: 1.3702
# Client client_9 - Accuracy: 0.4680, Loss: 1.5847
# ---- End of Round ----
#
# ---- Round 1 ----
# Client client_0 - Accuracy: 0.6620, Loss: 1.4376
# Client client_1 - Accuracy: 0.5780, Loss: 1.7433
# Client client_2 - Accuracy: 0.3700, Loss: 2.6931
# Client client_3 - Accuracy: 0.4300, Loss: 2.3291
# Client client_4 - Accuracy: 0.5330, Loss: 1.7522
# Client client_5 - Accuracy: 0.6050, Loss: 1.4790
# Client client_6 - Accuracy: 0.6480, Loss: 1.3759
# Client client_7 - Accuracy: 0.5970, Loss: 1.5808
# Client client_8 - Accuracy: 0.5290, Loss: 1.9964
# Client client_9 - Accuracy: 0.5350, Loss: 2.1162
# ---- End of Round ----
#
# ---- Round 2 ----
# Client client_0 - Accuracy: 0.6700, Loss: 1.4960
# Client client_1 - Accuracy: 0.6040, Loss: 1.7900
# Client client_2 - Accuracy: 0.4030, Loss: 2.7906
# Client client_3 - Accuracy: 0.4310, Loss: 2.4401
# Client client_4 - Accuracy: 0.5180, Loss: 1.9467
# Client client_5 - Accuracy: 0.6040, Loss: 1.6277
# Client client_6 - Accuracy: 0.6480, Loss: 1.4783
# Client client_7 - Accuracy: 0.6170, Loss: 1.6430
# Client client_8 - Accuracy: 0.5460, Loss: 2.1194
# Client client_9 - Accuracy: 0.5310, Loss: 2.3251
# ---- End of Round ----
#
# ---- Round 3 ----
# Client client_0 - Accuracy: 0.6730, Loss: 1.5115
# Client client_1 - Accuracy: 0.6040, Loss: 1.9054
# Client client_2 - Accuracy: 0.4120, Loss: 2.9750
# Client client_3 - Accuracy: 0.4560, Loss: 2.5758
# Client client_4 - Accuracy: 0.5380, Loss: 2.0916
# Client client_5 - Accuracy: 0.6130, Loss: 1.7254
# Client client_6 - Accuracy: 0.6600, Loss: 1.4707
# Client client_7 - Accuracy: 0.6300, Loss: 1.6629
# Client client_8 - Accuracy: 0.5530, Loss: 2.2823
# Client client_9 - Accuracy: 0.5360, Loss: 2.4539
# ---- End of Round ----
#
# ---- Round 4 ----
# Client client_0 - Accuracy: 0.7020, Loss: 1.4593
# Client client_1 - Accuracy: 0.6180, Loss: 1.9186
# Client client_2 - Accuracy: 0.4120, Loss: 3.0276
# Client client_3 - Accuracy: 0.4640, Loss: 2.5470
# Client client_4 - Accuracy: 0.5360, Loss: 2.0499
# Client client_5 - Accuracy: 0.6090, Loss: 1.7324
# Client client_6 - Accuracy: 0.6590, Loss: 1.5263
# Client client_7 - Accuracy: 0.6180, Loss: 1.7381
# Client client_8 - Accuracy: 0.5300, Loss: 2.4265
# Client client_9 - Accuracy: 0.5320, Loss: 2.5391
# ---- End of Round ----
#
# ---- Round 5 ----
# Client client_0 - Accuracy: 0.6780, Loss: 1.5760
# Client client_1 - Accuracy: 0.6100, Loss: 2.0032
# Client client_2 - Accuracy: 0.4040, Loss: 3.1688
# Client client_3 - Accuracy: 0.4440, Loss: 2.7393
# Client client_4 - Accuracy: 0.5420, Loss: 2.1473
# Client client_5 - Accuracy: 0.6350, Loss: 1.7435
# Client client_6 - Accuracy: 0.6790, Loss: 1.5233
# Client client_7 - Accuracy: 0.6340, Loss: 1.6840
# Client client_8 - Accuracy: 0.5440, Loss: 2.3519
# Client client_9 - Accuracy: 0.5260, Loss: 2.5896
# ---- End of Round ----
#
# ---- Round 6 ----
# Client client_0 - Accuracy: 0.7020, Loss: 1.4782
# Client client_1 - Accuracy: 0.6330, Loss: 1.9145
# Client client_2 - Accuracy: 0.4250, Loss: 3.0376
# Client client_3 - Accuracy: 0.4650, Loss: 2.6836
# Client client_4 - Accuracy: 0.5450, Loss: 2.2064
# Client client_5 - Accuracy: 0.6270, Loss: 1.7961
# Client client_6 - Accuracy: 0.6850, Loss: 1.5229
# Client client_7 - Accuracy: 0.6400, Loss: 1.7554
# Client client_8 - Accuracy: 0.5480, Loss: 2.5138
# Client client_9 - Accuracy: 0.5420, Loss: 2.6021
# ---- End of Round ----
#
# ---- Round 7 ----
# Client client_0 - Accuracy: 0.7040, Loss: 1.5024
# Client client_1 - Accuracy: 0.6200, Loss: 2.0405
# Client client_2 - Accuracy: 0.4240, Loss: 3.1643
# Client client_3 - Accuracy: 0.4800, Loss: 2.6888
# Client client_4 - Accuracy: 0.5640, Loss: 2.1367
# Client client_5 - Accuracy: 0.6250, Loss: 1.7948
# Client client_6 - Accuracy: 0.6860, Loss: 1.5236
# Client client_7 - Accuracy: 0.6600, Loss: 1.6560
# Client client_8 - Accuracy: 0.5710, Loss: 2.3165
# Client client_9 - Accuracy: 0.5680, Loss: 2.4518
# ---- End of Round ----
#
# ---- Round 8 ----
# Client client_0 - Accuracy: 0.7110, Loss: 1.4401
# Client client_1 - Accuracy: 0.6120, Loss: 2.0432
# Client client_2 - Accuracy: 0.4220, Loss: 3.2027
# Client client_3 - Accuracy: 0.4690, Loss: 2.7573
# Client client_4 - Accuracy: 0.5400, Loss: 2.2219
# Client client_5 - Accuracy: 0.6120, Loss: 1.8710
# Client client_6 - Accuracy: 0.6730, Loss: 1.5653
# Client client_7 - Accuracy: 0.6440, Loss: 1.7066
# Client client_8 - Accuracy: 0.5830, Loss: 2.3404
# Client client_9 - Accuracy: 0.5910, Loss: 2.3858
# ---- End of Round ----
#
# ---- Round 9 ----
# Client client_0 - Accuracy: 0.6960, Loss: 1.5307
# Client client_1 - Accuracy: 0.6320, Loss: 1.8947
# Client client_2 - Accuracy: 0.4340, Loss: 3.0083
# Client client_3 - Accuracy: 0.4670, Loss: 2.7424
# Client client_4 - Accuracy: 0.5370, Loss: 2.3025
# Client client_5 - Accuracy: 0.6180, Loss: 1.8312
# Client client_6 - Accuracy: 0.6810, Loss: 1.5193
# Client client_7 - Accuracy: 0.6500, Loss: 1.7225
# Client client_8 - Accuracy: 0.5750, Loss: 2.3616
# Client client_9 - Accuracy: 0.5570, Loss: 2.5239
# ---- End of Round ----
#
# ---- Round 10 ----
# Client client_0 - Accuracy: 0.7020, Loss: 1.5290
# Client client_1 - Accuracy: 0.6430, Loss: 1.9236
# Client client_2 - Accuracy: 0.4580, Loss: 2.9648
# Client client_3 - Accuracy: 0.4860, Loss: 2.6463
# Client client_4 - Accuracy: 0.5560, Loss: 2.2298
# Client client_5 - Accuracy: 0.6310, Loss: 1.8296
# Client client_6 - Accuracy: 0.6930, Loss: 1.5473
# Client client_7 - Accuracy: 0.6470, Loss: 1.7169
# Client client_8 - Accuracy: 0.5780, Loss: 2.2999
# Client client_9 - Accuracy: 0.5830, Loss: 2.4483
# ---- End of Round ----
#
# ---- Round 11 ----
# Client client_0 - Accuracy: 0.7190, Loss: 1.4776
# Client client_1 - Accuracy: 0.6440, Loss: 1.9298
# Client client_2 - Accuracy: 0.4440, Loss: 3.0981
# Client client_3 - Accuracy: 0.4960, Loss: 2.6170
# Client client_4 - Accuracy: 0.5700, Loss: 2.1096
# Client client_5 - Accuracy: 0.6210, Loss: 1.8602
# Client client_6 - Accuracy: 0.6820, Loss: 1.5986
# Client client_7 - Accuracy: 0.6640, Loss: 1.6797
# Client client_8 - Accuracy: 0.5960, Loss: 2.3224
# Client client_9 - Accuracy: 0.5880, Loss: 2.5137
# ---- End of Round ----
#
# ---- Round 12 ----
# Client client_0 - Accuracy: 0.7190, Loss: 1.5351
# Client client_1 - Accuracy: 0.6420, Loss: 1.9521
# Client client_2 - Accuracy: 0.4360, Loss: 3.1510
# Client client_3 - Accuracy: 0.4820, Loss: 2.7449
# Client client_4 - Accuracy: 0.5590, Loss: 2.2627
# Client client_5 - Accuracy: 0.6170, Loss: 1.9082
# Client client_6 - Accuracy: 0.7010, Loss: 1.5062
# Client client_7 - Accuracy: 0.6850, Loss: 1.6290
# Client client_8 - Accuracy: 0.6060, Loss: 2.3135
# Client client_9 - Accuracy: 0.5960, Loss: 2.5287
# ---- End of Round ----
#
# ---- Round 13 ----
# Client client_0 - Accuracy: 0.7270, Loss: 1.4864
# Client client_1 - Accuracy: 0.6520, Loss: 1.9357
# Client client_2 - Accuracy: 0.4570, Loss: 3.0391
# Client client_3 - Accuracy: 0.5020, Loss: 2.6616
# Client client_4 - Accuracy: 0.5740, Loss: 2.1810
# Client client_5 - Accuracy: 0.6380, Loss: 1.7856
# Client client_6 - Accuracy: 0.6970, Loss: 1.4922
# Client client_7 - Accuracy: 0.6680, Loss: 1.6420
# Client client_8 - Accuracy: 0.5950, Loss: 2.3235
# Client client_9 - Accuracy: 0.5910, Loss: 2.4939
# ---- End of Round ----
#
# ---- Round 14 ----
# Client client_0 - Accuracy: 0.7090, Loss: 1.6000
# Client client_1 - Accuracy: 0.6460, Loss: 1.9392
# Client client_2 - Accuracy: 0.4400, Loss: 3.1682
# Client client_3 - Accuracy: 0.4820, Loss: 2.7636
# Client client_4 - Accuracy: 0.5650, Loss: 2.2260
# Client client_5 - Accuracy: 0.6330, Loss: 1.8335
# Client client_6 - Accuracy: 0.6910, Loss: 1.5387
# Client client_7 - Accuracy: 0.6470, Loss: 1.7383
# Client client_8 - Accuracy: 0.5780, Loss: 2.3469
# Client client_9 - Accuracy: 0.5770, Loss: 2.6096
# ---- End of Round ----
#
# ---- Round 15 ----
# Client client_0 - Accuracy: 0.7080, Loss: 1.5057
# Client client_1 - Accuracy: 0.6410, Loss: 1.8790
# Client client_2 - Accuracy: 0.4440, Loss: 3.0350
# Client client_3 - Accuracy: 0.4700, Loss: 2.7299
# Client client_4 - Accuracy: 0.5430, Loss: 2.2355
# Client client_5 - Accuracy: 0.6350, Loss: 1.7895
# Client client_6 - Accuracy: 0.7090, Loss: 1.4417
# Client client_7 - Accuracy: 0.6920, Loss: 1.5202
# Client client_8 - Accuracy: 0.6100, Loss: 2.1816
# Client client_9 - Accuracy: 0.5760, Loss: 2.4925
# ---- End of Round ----
#
# ---- Round 16 ----
# Client client_0 - Accuracy: 0.7280, Loss: 1.4983
# Client client_1 - Accuracy: 0.6400, Loss: 2.0318
# Client client_2 - Accuracy: 0.4230, Loss: 3.1890
# Client client_3 - Accuracy: 0.4890, Loss: 2.6273
# Client client_4 - Accuracy: 0.5820, Loss: 2.1299
# Client client_5 - Accuracy: 0.6370, Loss: 1.8373
# Client client_6 - Accuracy: 0.6940, Loss: 1.4998
# Client client_7 - Accuracy: 0.6690, Loss: 1.6047
# Client client_8 - Accuracy: 0.5990, Loss: 2.2786
# Client client_9 - Accuracy: 0.5930, Loss: 2.5024
# ---- End of Round ----
#
# ---- Round 17 ----
# Client client_0 - Accuracy: 0.7300, Loss: 1.4985
# Client client_1 - Accuracy: 0.6490, Loss: 1.9991
# Client client_2 - Accuracy: 0.4340, Loss: 3.2839
# Client client_3 - Accuracy: 0.4960, Loss: 2.7831
# Client client_4 - Accuracy: 0.5830, Loss: 2.2051
# Client client_5 - Accuracy: 0.6440, Loss: 1.8568
# Client client_6 - Accuracy: 0.7010, Loss: 1.4863
# Client client_7 - Accuracy: 0.6740, Loss: 1.6228
# Client client_8 - Accuracy: 0.6020, Loss: 2.2882
# Client client_9 - Accuracy: 0.5890, Loss: 2.5001
# ---- End of Round ----
#
# ---- Round 18 ----
# Client client_0 - Accuracy: 0.7190, Loss: 1.5885
# Client client_1 - Accuracy: 0.6390, Loss: 2.0346
# Client client_2 - Accuracy: 0.4200, Loss: 3.2389
# Client client_3 - Accuracy: 0.4850, Loss: 2.7754
# Client client_4 - Accuracy: 0.5780, Loss: 2.2407
# Client client_5 - Accuracy: 0.6340, Loss: 1.9341
# Client client_6 - Accuracy: 0.6940, Loss: 1.6234
# Client client_7 - Accuracy: 0.6670, Loss: 1.7042
# Client client_8 - Accuracy: 0.6240, Loss: 2.2206
# Client client_9 - Accuracy: 0.6120, Loss: 2.4762
# ---- End of Round ----
#
# ---- Round 19 ----
# Client client_0 - Accuracy: 0.6870, Loss: 1.7028
# Client client_1 - Accuracy: 0.6170, Loss: 2.1969
# Client client_2 - Accuracy: 0.4290, Loss: 3.3536
# Client client_3 - Accuracy: 0.4920, Loss: 2.8037
# Client client_4 - Accuracy: 0.5790, Loss: 2.2567
# Client client_5 - Accuracy: 0.6520, Loss: 1.8883
# Client client_6 - Accuracy: 0.7120, Loss: 1.5717
# Client client_7 - Accuracy: 0.6710, Loss: 1.7436
# Client client_8 - Accuracy: 0.5980, Loss: 2.2787
# Client client_9 - Accuracy: 0.5750, Loss: 2.5340
# ---- End of Round ----
#
# ---- Round 20 ----
# Client client_0 - Accuracy: 0.7170, Loss: 1.4701
# Client client_1 - Accuracy: 0.6520, Loss: 1.9254
# Client client_2 - Accuracy: 0.4500, Loss: 3.1232
# Client client_3 - Accuracy: 0.4910, Loss: 2.7230
# Client client_4 - Accuracy: 0.5830, Loss: 2.2440
# Client client_5 - Accuracy: 0.6490, Loss: 1.8522
# Client client_6 - Accuracy: 0.7100, Loss: 1.4694
# Client client_7 - Accuracy: 0.6840, Loss: 1.5938
# Client client_8 - Accuracy: 0.6120, Loss: 2.2110
# Client client_9 - Accuracy: 0.5980, Loss: 2.4227
# ---- End of Round ----
#
# ---- Round 21 ----
# Client client_0 - Accuracy: 0.7300, Loss: 1.4806
# Client client_1 - Accuracy: 0.6550, Loss: 1.9896
# Client client_2 - Accuracy: 0.4480, Loss: 3.2060
# Client client_3 - Accuracy: 0.4930, Loss: 2.6877
# Client client_4 - Accuracy: 0.5750, Loss: 2.1405
# Client client_5 - Accuracy: 0.6400, Loss: 1.8555
# Client client_6 - Accuracy: 0.7040, Loss: 1.5298
# Client client_7 - Accuracy: 0.6910, Loss: 1.6290
# Client client_8 - Accuracy: 0.6160, Loss: 2.3202
# Client client_9 - Accuracy: 0.5970, Loss: 2.5040
# ---- End of Round ----
#
# ---- Round 22 ----
# Client client_0 - Accuracy: 0.7260, Loss: 1.5192
# Client client_1 - Accuracy: 0.6640, Loss: 1.9173
# Client client_2 - Accuracy: 0.4630, Loss: 3.1192
# Client client_3 - Accuracy: 0.4860, Loss: 2.7870
# Client client_4 - Accuracy: 0.5700, Loss: 2.2166
# Client client_5 - Accuracy: 0.6520, Loss: 1.8040
# Client client_6 - Accuracy: 0.7080, Loss: 1.5456
# Client client_7 - Accuracy: 0.6810, Loss: 1.6794
# Client client_8 - Accuracy: 0.6240, Loss: 2.2520
# Client client_9 - Accuracy: 0.6100, Loss: 2.4572
# ---- End of Round ----
#
# ---- Round 23 ----
# Client client_0 - Accuracy: 0.7280, Loss: 1.5053
# Client client_1 - Accuracy: 0.6500, Loss: 1.9669
# Client client_2 - Accuracy: 0.4560, Loss: 3.1625
# Client client_3 - Accuracy: 0.5000, Loss: 2.7183
# Client client_4 - Accuracy: 0.5860, Loss: 2.1075
# Client client_5 - Accuracy: 0.6560, Loss: 1.7528
# Client client_6 - Accuracy: 0.7060, Loss: 1.5168
# Client client_7 - Accuracy: 0.6800, Loss: 1.6249
# Client client_8 - Accuracy: 0.6050, Loss: 2.2869
# Client client_9 - Accuracy: 0.5960, Loss: 2.5239
# ---- End of Round ----
#
# ---- Round 24 ----
# Client client_0 - Accuracy: 0.7130, Loss: 1.5986
# Client client_1 - Accuracy: 0.6490, Loss: 1.9818
# Client client_2 - Accuracy: 0.4430, Loss: 3.1726
# Client client_3 - Accuracy: 0.4990, Loss: 2.7394
# Client client_4 - Accuracy: 0.5860, Loss: 2.1815
# Client client_5 - Accuracy: 0.6580, Loss: 1.8134
# Client client_6 - Accuracy: 0.7290, Loss: 1.5377
# Client client_7 - Accuracy: 0.6940, Loss: 1.7075
# Client client_8 - Accuracy: 0.6090, Loss: 2.3901
# Client client_9 - Accuracy: 0.5810, Loss: 2.6331
# ---- End of Round ----
#
# ---- Round 25 ----
# Client client_0 - Accuracy: 0.7470, Loss: 1.5053
# Client client_1 - Accuracy: 0.6440, Loss: 2.0768
# Client client_2 - Accuracy: 0.4310, Loss: 3.3332
# Client client_3 - Accuracy: 0.4840, Loss: 2.8494
# Client client_4 - Accuracy: 0.5860, Loss: 2.2083
# Client client_5 - Accuracy: 0.6620, Loss: 1.7973
# Client client_6 - Accuracy: 0.7160, Loss: 1.5484
# Client client_7 - Accuracy: 0.6940, Loss: 1.7044
# Client client_8 - Accuracy: 0.6370, Loss: 2.2441
# Client client_9 - Accuracy: 0.6330, Loss: 2.4154
# ---- End of Round ----
#
# ---- Round 26 ----
# Client client_0 - Accuracy: 0.7190, Loss: 1.5819
# Client client_1 - Accuracy: 0.6500, Loss: 2.0043
# Client client_2 - Accuracy: 0.4470, Loss: 3.2411
# Client client_3 - Accuracy: 0.4790, Loss: 2.8638
# Client client_4 - Accuracy: 0.5700, Loss: 2.2842
# Client client_5 - Accuracy: 0.6450, Loss: 1.8677
# Client client_6 - Accuracy: 0.7000, Loss: 1.5780
# Client client_7 - Accuracy: 0.6770, Loss: 1.7552
# Client client_8 - Accuracy: 0.6250, Loss: 2.2774
# Client client_9 - Accuracy: 0.6110, Loss: 2.4736
# ---- End of Round ----
#
# ---- Round 27 ----
# Client client_0 - Accuracy: 0.7250, Loss: 1.5568
# Client client_1 - Accuracy: 0.6560, Loss: 1.9823
# Client client_2 - Accuracy: 0.4450, Loss: 3.2996
# Client client_3 - Accuracy: 0.4780, Loss: 2.8708
# Client client_4 - Accuracy: 0.5730, Loss: 2.2474
# Client client_5 - Accuracy: 0.6530, Loss: 1.8852
# Client client_6 - Accuracy: 0.7030, Loss: 1.5921
# Client client_7 - Accuracy: 0.6790, Loss: 1.7410
# Client client_8 - Accuracy: 0.6080, Loss: 2.3569
# Client client_9 - Accuracy: 0.5890, Loss: 2.5673
# ---- End of Round ----
#
# ---- Round 28 ----
# Client client_0 - Accuracy: 0.7360, Loss: 1.5727
# Client client_1 - Accuracy: 0.6720, Loss: 2.0434
# Client client_2 - Accuracy: 0.4580, Loss: 3.3777
# Client client_3 - Accuracy: 0.4980, Loss: 2.9121
# Client client_4 - Accuracy: 0.5790, Loss: 2.3136
# Client client_5 - Accuracy: 0.6470, Loss: 1.9179
# Client client_6 - Accuracy: 0.7210, Loss: 1.5161
# Client client_7 - Accuracy: 0.6970, Loss: 1.6519
# Client client_8 - Accuracy: 0.6260, Loss: 2.3411
# Client client_9 - Accuracy: 0.6060, Loss: 2.5976
# ---- End of Round ----
#
# ---- Round 29 ----
# Client client_0 - Accuracy: 0.7460, Loss: 1.4653
# Client client_1 - Accuracy: 0.6620, Loss: 1.9851
# Client client_2 - Accuracy: 0.4540, Loss: 3.3137
# Client client_3 - Accuracy: 0.4960, Loss: 2.8851
# Client client_4 - Accuracy: 0.5740, Loss: 2.2602
# Client client_5 - Accuracy: 0.6450, Loss: 1.8995
# Client client_6 - Accuracy: 0.7090, Loss: 1.5582
# Client client_7 - Accuracy: 0.6660, Loss: 1.8081
# Client client_8 - Accuracy: 0.6160, Loss: 2.3963
# Client client_9 - Accuracy: 0.6290, Loss: 2.4164
# ---- End of Round ----
#
# ---- Round 30 ----
# Client client_0 - Accuracy: 0.7170, Loss: 1.6681
# Client client_1 - Accuracy: 0.6580, Loss: 2.1080
# Client client_2 - Accuracy: 0.4530, Loss: 3.4751
# Client client_3 - Accuracy: 0.4920, Loss: 2.9515
# Client client_4 - Accuracy: 0.5650, Loss: 2.3506
# Client client_5 - Accuracy: 0.6400, Loss: 1.9473
# Client client_6 - Accuracy: 0.7120, Loss: 1.5235
# Client client_7 - Accuracy: 0.6910, Loss: 1.6629
# Client client_8 - Accuracy: 0.6270, Loss: 2.3121
# Client client_9 - Accuracy: 0.5930, Loss: 2.6586
# ---- End of Round ----
#
# ---- Round 31 ----
# Client client_0 - Accuracy: 0.7180, Loss: 1.6512
# Client client_1 - Accuracy: 0.6620, Loss: 2.0649
# Client client_2 - Accuracy: 0.4590, Loss: 3.2748
# Client client_3 - Accuracy: 0.4930, Loss: 2.8199
# Client client_4 - Accuracy: 0.5700, Loss: 2.3228
# Client client_5 - Accuracy: 0.6470, Loss: 1.9181
# Client client_6 - Accuracy: 0.7170, Loss: 1.5680
# Client client_7 - Accuracy: 0.7020, Loss: 1.6704
# Client client_8 - Accuracy: 0.6340, Loss: 2.2245
# Client client_9 - Accuracy: 0.5940, Loss: 2.5595
# ---- End of Round ----
#
# ---- Round 32 ----
# Client client_0 - Accuracy: 0.7400, Loss: 1.5405
# Client client_1 - Accuracy: 0.6690, Loss: 1.9375
# Client client_2 - Accuracy: 0.4510, Loss: 3.3583
# Client client_3 - Accuracy: 0.4780, Loss: 3.0083
# Client client_4 - Accuracy: 0.5670, Loss: 2.3365
# Client client_5 - Accuracy: 0.6480, Loss: 1.8715
# Client client_6 - Accuracy: 0.7140, Loss: 1.5142
# Client client_7 - Accuracy: 0.7020, Loss: 1.6198
# Client client_8 - Accuracy: 0.6370, Loss: 2.1862
# Client client_9 - Accuracy: 0.6120, Loss: 2.4890
# ---- End of Round ----
#
# ---- Round 33 ----
# Client client_0 - Accuracy: 0.7350, Loss: 1.5600
# Client client_1 - Accuracy: 0.6550, Loss: 2.0909
# Client client_2 - Accuracy: 0.4550, Loss: 3.4174
# Client client_3 - Accuracy: 0.5120, Loss: 2.9422
# Client client_4 - Accuracy: 0.6020, Loss: 2.2799
# Client client_5 - Accuracy: 0.6710, Loss: 1.8475
# Client client_6 - Accuracy: 0.7280, Loss: 1.5185
# Client client_7 - Accuracy: 0.6930, Loss: 1.7244
# Client client_8 - Accuracy: 0.6250, Loss: 2.3771
# Client client_9 - Accuracy: 0.6140, Loss: 2.5444
# ---- End of Round ----
#
# ---- Round 34 ----
# Client client_0 - Accuracy: 0.7380, Loss: 1.6224
# Client client_1 - Accuracy: 0.6600, Loss: 2.0665
# Client client_2 - Accuracy: 0.4560, Loss: 3.4586
# Client client_3 - Accuracy: 0.5010, Loss: 3.0205
# Client client_4 - Accuracy: 0.5850, Loss: 2.2881
# Client client_5 - Accuracy: 0.6640, Loss: 1.7926
# Client client_6 - Accuracy: 0.7210, Loss: 1.5236
# Client client_7 - Accuracy: 0.6890, Loss: 1.7685
# Client client_8 - Accuracy: 0.6330, Loss: 2.3918
# Client client_9 - Accuracy: 0.6200, Loss: 2.6293
# ---- End of Round ----
#
# ---- Round 35 ----
# Client client_0 - Accuracy: 0.7240, Loss: 1.6038
# Client client_1 - Accuracy: 0.6430, Loss: 2.2088
# Client client_2 - Accuracy: 0.4520, Loss: 3.5281
# Client client_3 - Accuracy: 0.5080, Loss: 2.9658
# Client client_4 - Accuracy: 0.5820, Loss: 2.3056
# Client client_5 - Accuracy: 0.6550, Loss: 1.8396
# Client client_6 - Accuracy: 0.7240, Loss: 1.4752
# Client client_7 - Accuracy: 0.6870, Loss: 1.6730
# Client client_8 - Accuracy: 0.6130, Loss: 2.3476
# Client client_9 - Accuracy: 0.6020, Loss: 2.5684
# ---- End of Round ----
#
# ---- Round 36 ----
# Client client_0 - Accuracy: 0.7310, Loss: 1.5974
# Client client_1 - Accuracy: 0.6410, Loss: 2.1484
# Client client_2 - Accuracy: 0.4480, Loss: 3.4328
# Client client_3 - Accuracy: 0.5160, Loss: 2.9193
# Client client_4 - Accuracy: 0.6100, Loss: 2.2029
# Client client_5 - Accuracy: 0.6670, Loss: 1.7787
# Client client_6 - Accuracy: 0.7160, Loss: 1.5334
# Client client_7 - Accuracy: 0.7090, Loss: 1.6415
# Client client_8 - Accuracy: 0.6540, Loss: 2.1973
# Client client_9 - Accuracy: 0.6260, Loss: 2.4643
# ---- End of Round ----
#
# ---- Round 37 ----
# Client client_0 - Accuracy: 0.7410, Loss: 1.4919
# Client client_1 - Accuracy: 0.6750, Loss: 1.9879
# Client client_2 - Accuracy: 0.4770, Loss: 3.2539
# Client client_3 - Accuracy: 0.5180, Loss: 2.8347
# Client client_4 - Accuracy: 0.5990, Loss: 2.2145
# Client client_5 - Accuracy: 0.6540, Loss: 1.8452
# Client client_6 - Accuracy: 0.7100, Loss: 1.5728
# Client client_7 - Accuracy: 0.6990, Loss: 1.6590
# Client client_8 - Accuracy: 0.6470, Loss: 2.2587
# Client client_9 - Accuracy: 0.6280, Loss: 2.4675
# ---- End of Round ----
#
# ---- Round 38 ----
# Client client_0 - Accuracy: 0.7340, Loss: 1.5592
# Client client_1 - Accuracy: 0.6600, Loss: 2.0879
# Client client_2 - Accuracy: 0.4630, Loss: 3.2905
# Client client_3 - Accuracy: 0.5180, Loss: 2.7723
# Client client_4 - Accuracy: 0.6050, Loss: 2.1648
# Client client_5 - Accuracy: 0.6690, Loss: 1.7782
# Client client_6 - Accuracy: 0.7200, Loss: 1.5640
# Client client_7 - Accuracy: 0.7090, Loss: 1.6829
# Client client_8 - Accuracy: 0.6520, Loss: 2.2034
# Client client_9 - Accuracy: 0.6180, Loss: 2.4591
# ---- End of Round ----
#
# ---- Round 39 ----
# Client client_0 - Accuracy: 0.7330, Loss: 1.5684
# Client client_1 - Accuracy: 0.6440, Loss: 2.1939
# Client client_2 - Accuracy: 0.4520, Loss: 3.5038
# Client client_3 - Accuracy: 0.5070, Loss: 2.9831
# Client client_4 - Accuracy: 0.5910, Loss: 2.3073
# Client client_5 - Accuracy: 0.6740, Loss: 1.7881
# Client client_6 - Accuracy: 0.7370, Loss: 1.4629
# Client client_7 - Accuracy: 0.7030, Loss: 1.6644
# Client client_8 - Accuracy: 0.6580, Loss: 2.2424
# Client client_9 - Accuracy: 0.6430, Loss: 2.4496
# ---- End of Round ----

# %%
#トレインデータ全体を合わせて1つのモデルにしたモデル
# すべてのクライアントのトレインデータ結合
combined_train_data = []
combined_train_labels = []

for client_name in client_names:
    client_train_data, client_train_labels = zip(*client_data[client_name])
    combined_train_data.extend(client_train_data)
    combined_train_labels.extend(client_train_labels)

combined_train_data = np.array(combined_train_data)
combined_train_labels = np.array(combined_train_labels)

# 統合されたデータセットでモデルトレーニング
combined_model = MLP().build()
combined_model.compile(loss=loss, optimizer=new_optimizer, metrics=metrics)
combined_model.fit(combined_train_data, combined_train_labels, epochs=20, verbose=0)

# 統合モデルを使用して各クライアントのテストデータ評価
combined_results = evaluate_model_on_clients(combined_model, client_test_data, client_names)

# 統合モデルの評価結果出力
print("Results for the combined model:")
for client, results in combined_results.items():
    print(f"  Test on {client} - Accuracy: {results['accuracy']:.4f}, Loss: {results['loss']:.4f}")

K.clear_session()
# Out:
# Results for the combined model:
#   Test on client_0 - Accuracy: 0.7880, Loss: 0.9239
#   Test on client_1 - Accuracy: 0.7120, Loss: 1.2584
#   Test on client_2 - Accuracy: 0.5890, Loss: 1.8406
#   Test on client_3 - Accuracy: 0.6440, Loss: 1.5871
#   Test on client_4 - Accuracy: 0.6820, Loss: 1.3743
#   Test on client_5 - Accuracy: 0.7130, Loss: 1.2636
#   Test on client_6 - Accuracy: 0.7460, Loss: 1.2066
#   Test on client_7 - Accuracy: 0.7900, Loss: 1.0124
#   Test on client_8 - Accuracy: 0.8020, Loss: 1.0127
#   Test on client_9 - Accuracy: 0.7500, Loss: 1.2166

# %%
combined_results = {
    "client_0": {'accuracy': 0.7880},
    "client_1": {'accuracy': 0.7120},
    "client_2": {'accuracy': 0.5890},
    "client_3": {'accuracy': 0.6440},
    "client_4": {'accuracy': 0.6820},
    "client_5": {'accuracy': 0.7130},
    "client_6": {'accuracy': 0.7460},
    "client_7": {'accuracy': 0.7900},
    "client_8": {'accuracy': 0.8020},
    "client_9": {'accuracy': 0.7500}
}

accuracies = [combined_results[f'client_{i}']['accuracy'] for i in range(10)]

clients = [f'Client {i}' for i in range(10)]

plt.figure(figsize=(8, 6))
plt.bar(clients, accuracies, color='skyblue')
plt.xlabel('Client')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.title('Accuracy of Combined Model on Each Client Test Data(5:1)')
plt.show()
